# %% [markdown]
# ### Transfermarkt 크롤링
# - 첫페이지 25명 정보

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# requsts.get()으로 url정보 요청하기 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
(KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}

url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url, headers=headers)
r.status_code  # 200이 나오면 정상
# Out:
# 200

# %%
# BeautifulSoup()으로 웹페이지 분석 준비하기
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#1a3151" name="theme-color">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport">
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" property="og:url"/>
# <link href="https://www.transfermarkt.de/marktwertetop/wertvollstespieler" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/marktwertetop/wertvollstespieler" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/marktwertetop/wertvollstespieler" hreflang="de-AT" rel="alternate">
# <link href="https://www.transfermarkt.ch/marktwertetop/wertvollstespieler" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/marktwertetop/wertvollstespieler" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/marktwertetop/wertvollstespieler" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/marktwertetop/wertvollstespieler" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/marktwertetop/wertvollstespieler" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/marktwertetop/wertvollstespieler" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/marktwertetop/wertvollstespieler" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/marktwertetop/wertvollstespieler" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/marktwertetop/wertvollstespieler" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.ru/marktwertetop/wertvollstespieler" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/marktwertetop/wertvollstespieler" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/marktwertetop/wertvollstespieler" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/marktwertetop/wertvollstespieler" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/marktwertetop/wertvollstespieler" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/marktwertetop/wertvollstespieler" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/marktwertetop/wertvollstespieler" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/marktwertetop/wertvollstespieler" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/marktwertetop/wertvollstespieler" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/marktwertetop/wertvollstespieler" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.my/marktwertetop/wertvollstespieler" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/marktwertetop/wertvollstespieler" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/marktwertetop/wertvollstespieler" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/tm-grid.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.css?lm=1633521646" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/foundation-icons.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jui/css/base/jquery-ui.css?lm=1633521680" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/sprite-main.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.custom.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.tm-theme.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_werbung.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/shortclasses.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1633521677" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/desktop.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/domainspezifisch/desktop-com.css?lm=1633521678" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/gridview.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1633521677" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/css/tooltipster.css?lm=1633521680" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1633521680" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1633521680" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1633521680" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/localStorage.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/foundation.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery-ui-1.10.4.custom.min.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/clipboard.min.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1633521674" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery.icheck.min.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/js/jquery.tooltipster.js?lm=1633521680" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <script src="https://tmsi.akamaized.net/js/globals/tm-global-elements.esm.js" type="module">
# /*<![CDATA[*/
#
# /*]]>*/
# </script><script nomodule="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.js" type="text/javascript">
# /*<![CDATA[*/
#
# /*]]>*/
# </script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script><!--  SZM 2.0 (IVW/AGOF) -->
# <script src="https://script.ioam.de/iam.js" type="text/javascript"></script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#         if (self == top) {
#             document.documentElement.style.display = 'block';
#         } else {
#             top.location = self.location;
#         }
#     </script>
# <noscript>
# <style>
#             html body *:not(.noscript) {
#                 display: none;
#             }
#         </style>
# <div class="noscript">
#             To use this site, please enable Javascript.        </div>
# </noscript>
# <!--[if lte IE 8]>
#     <link rel="stylesheet" type="text/css" href="/css/ie.css"/><![endif]-->
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 09113715 */ !function(t,e){function n(t,e){var n=pt(t);if(!n)return n;if(""!=e)for(var i=0;i<e.length;i++){var r=u(e,i);"^"==r&&(n=n.parentNode),"<"==r&&(n=n.previousElementSibling),">"==r&&(n=n.nextElementSibling),"y"==r&&(n=n.firstChild)}return n}function i(t,e){var n=rt(e);return{x:t.clientX-n.left,y:t.clientY-n.top}}function r(t){for(var e=0,n=0;t;)e+=t.offsetLeft+t.clientLeft,n+=t.offsetTop+t.clientTop,t=t.offsetParent;return{x:e,y:n}}function d(t,e){var n=0,i=0,d=r(e);return(t.pageX||t.pageY)&&(n=t.pageX,i=t.pageY),(t.clientX||t.clientY)&&(n=t.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,i=t.clientY+document.body.scrollTop+document.documentElement.scrollTop),n-=d.x,i-=d.y,{x:n,y:i}}function o(t,e){return it(e)?i(t,e):d(t,e)}function w(t,e){t.addEventListener?b(t,"click",e,!0):t.attachEvent&&t.attachEvent("onclick",function(){return e.call(t,window.event)})}function l(e,n){return t[c("c2V0VGltZW91dA==")](e,n)}function f(t){return parseInt(t.toString().split(".")[0],10)}function u(t,e){return t[e]}function s(){return Pt=(St*Pt+Ot)%Xt}function a(){return s()/(Xt-1)}function p(){return a()}function x(t,e){return t>e?t:e}function h(){for(var t="",e=65;e<91;e++)t+=k(e);for(var e=97;e<123;e++)t+=k(e);return t}function k(t){return u(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+u("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}",t-32)}function c(t){var e,n,i,r,d,o,w,l=h()+"0123456789+/=",f="",s=0;for(t=t.replace(/[^A-Za-z0-9\+\/\=]/g,"");s<t.length;)r=l.indexOf(u(t,s++)),d=l.indexOf(u(t,s++)),o=l.indexOf(u(t,s++)),w=l.indexOf(u(t,s++)),e=r<<2|d>>4,n=(15&d)<<4|o>>2,i=(3&o)<<6|w,f+=k(e),64!=o&&(f+=k(n)),64!=w&&(f+=k(i));return f}function v(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(t){return"unknown"}}function b(t,e,n,i){i=i||!1;try{t.addEventListener(e,n,i)}catch(i){t.attachEvent&&t.attachEvent("on"+e,n)}}function z(t){if(!t)return"";for(var e=c("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),n="",i=0;i<t.length;i++){n+=e.indexOf(t[i])>-1?c("XA==")+t[i]:t[i]}return n}function R(t){if(!t)return"";var e="";return t.id&&t.id.length>0&&(e+="#"+z(t.id)),t.className&&t.className.length>0&&(e+="."+z(t.className).split(" ").filter(function(t){return t&&t.length>0}).join(".")),e}function m(t){Kt[t]=!1}function g(t,e){var n=It++;Kt[n]=!0;var i=function(e){return function(){t.call(null),Kt[n]&&l(i,e)}}(e);return l(i,e),n}function j(t){var e=!1;return Object.keys(t).forEach(function(n){e=e||t[n]}),!e}function y(t,e){return t&&(t.consents&&t.consents[e]||t.legitimateInterests&&t.legitimateInterests[e])}function q(e){return!!t.wbxtk677Flags.strictNCNA&&(y(e,2)&&y(e,7)&&y(e,9)&&y(e,10))}function E(t,e,n){var i=function(){return!!e()&&(n(),!0)};if(!i()){var r=g(function(){i()&&m(r)},250);i()}}function W(t){T(t)}function T(n){if(n.wbxtk544sdl&&!n.wbxtk10eInject){n.wbxtk10eInject=!0,n.wbxtk912Pc={},n.wbxtk1aaOc=[],n.wbxtk406Am={},n.wbxtka40Av={},n.wbxtk2daAw={},n.wbxtk436Rqr={},n.wbxtke92Rqq=[],n.wbxtka40Avt={},n.wbxtkd0dEv={};var i=[];if(t.wbxtk677Flags.video){var r=pt(".news-content > .news-widget--container + p, .news-content > .news-widget--container + p, .spielerDatenContainer + .viewport-tracking + div");if(r){var d=D("div");at(d,"ApOTEhvo"),nt(d,"margin","20px 0px");var o=D("div");st(o,"dfbndrgl"),function(e){if(!e){t.wbxtk677Flags.videoUnblockingPaused=!1,t.wbxtk677Flags.goForImageAndIframeRecovery=!0,nt(r,"padding","initial");var n=D("div");$(n,"class","publisher-sh-spot"),$(n,"data-player","941cedf3-2100-46ab-a724-d5bdb0b520ce");var i=D("script");$(i,"onload","window.SpotSHTag=this"),$(i,"src","https://static.showheroes.com/publishertag.js"),$(i,"data-noad-passback-listener","window.wbxtk677Flags.video_displayAsBackfill = true;"),i.async=!0,wt(r,d),B(d,n),B(d,i),lt(d,o)}}(t.wbxtk677Flags.ncna)}}if(!n.wbxtk677Flags.welect.eenabled||IZBKWWelect()){if(wbxtk677Flags.pt31fls){var w=wbxtk677Flags.ba806it,l=wbxtk677Flags.mb741el||10,u=wbxtk677Flags.ig8ddBP,s=function(){var t=D("st ...
# var w=[Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2i4ZfGh8w4L5w}h6J]:n8zGE3z[[<:[yGiHJKG{wNqlMI2"+t.wbxtkf47Rnd+"XLMZ3I]kUuf3VLhg|gR7K;t<eZNowLVwVt]Lrfu77ZRxYM91jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh28R4Fj[Vs7[rXKnH\\zX6Kik5WL53lzrPRjYQVjJ::<ifm2"+t.wbxtkf47Rnd+"T]UF[m[s3e3T3kkfQR}Q9uMP;VxtOJ9\\TI}3}<{S6Pl8p[t1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2qxzKtiEu\\e\\eZVkUrk[V5glYgm[XFJ\\zyr\\sxGN7o]{]2"+t.wbxtkf47Rnd+"EYLOR7yviHf:MigykNZ|fu<V6WyR:|4q7Sk:4}3jKx]<knf1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh268N3y:GOeSlwxHV[TtP4v9G:VwglM]9xNSUrFETLQwe|2"+t.wbxtkf47Rnd+"Y[TQ6eHo<wZ{IP9}eqM7IluNwESM4}lFONOX;[3oRYQK3jO1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2qMLo}\\3Q:Yxlq{QKmoJjI5]v9TJqYrf{xquZ6FFEZ}y]2"+t.wbxtkf47Rnd+"LEG7JV7X<oTGne[VgzfQ7:rN7vNhQGhvhX5UPOyqMWM]hi\\1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2zeR]yRp|lR{rlvvO5hZ;KJIHWxMemxeIz{Fyv3misoVO2"+t.wbxtkf47Rnd+"UYF][k9zPSu;YfVwYMjY;W4NeLNJ:\\Ff6Y88lzqf{SIEw[w1jli",-3)],l=[Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2PMufpMUQRpoqeVfXEgf4:Yj<|lq:FlPtH;fHLHR6}]G62"+t.wbxtkf47Rnd+"OVLKLs7\\e8Hqs]iZPGvIWlihV3<|:8FJXo5OjtHLtZgnGlj1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2RZgeTnvV[{xN4]8}F9H\\xVmvxqSuZ<ImkqUMljhpfEEX2"+t.wbxtkf47Rnd+"RLVN;hTnp7;:JYR6IOmZ[voFeGS7<3U|mXsKFqx7PLVX;p]1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2UnJR8T]MjT8hG\\h<Z]3vHVhy|jOR3zXIMuWv9R8Suo<]2"+t.wbxtkf47Rnd+"[HHR;rNxj8;ih6XTz3InV5KWxlpMQuO}{jixo7Zh]IR[gYV1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2yQ6k;\\]KET\\S[po6YnFMpP[3lNKPM;TFN:gi\\svqzeH}2"+t.wbxtkf47Rnd+"IPW\\:O498]]kZpjEt4LmQqiIyUM{MPezqyNOntpF}fyuy{h1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2qSxIjx]VMlWX[:5XIy;3omYuh3VyHPsqe<K5kh|4\\oW72"+t.wbxtkf47Rnd+"Y]Xxe7T3txjYklFf<}9MGQi;3kU6Z;yYQ;nZ{Sh:jTmTn[Y1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2LGzkwlnu3sgLxGzw98GTv<Xf4e|unh;e\\H<J}[S7Kx;q2"+t.wbxtkf47Rnd+"XIZG|xU8}fT<tpu<I{KL;N::T[6frvigYMxt9zE]<S|9VEf1jli",-3)],u=w[1*f(6*n.y/this.offsetHeight)+f(1*n.x/this.offsetWidth)],s=l[1*f(6*n.y/this.offsetHeight)+f(1*n.x/this.offsetWidth)];zt(t,u,s,"_blank")}}),B(s,l),wt(u,s),t.wbxtkd2804.a[9440]=s,M([{applyAdText:!0}],s,9440),Ht(s,9440,Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh25EM|w{gUG7O:e3XzKsw5R5J9{Q\\3|F[F7wmGh\\rpjv4U2"+t.wbxtkf47Rnd+"FK\\YPLT8ZJtkiUjoyyRT\\noyf[7jr{I\\Y:zMyqpGpg;zwSi1jli",-3)),X(9440,n,!0)}}},function(){X(9440,n,!1)})}function a(e,n,r,d){r||ht(Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2tV7zG<Kn9VpwXNGwxOutvtlPtYn8UZM6VfeesOtsE6K}2"+t.wbxtkf47Rnd+"ZOJN]jt7}O8O]zF3THJHRJvYek|iQlsRrhfe;VmfOLnv;5N1jli",-3),function(){if(!r){r=!0;var l=this;if(l.height<2)return void X(9931,n,!1);if(d==t.wbxtkf47Rnd){var u=e,s=D("div");i[""+c(Tt(c("V1o8bGRae29bMzRWUGpAQA=="),-3))]=s,st(s,"wlUWeaQExt ");var a=l;t.wbxtk406Am[9931]&&(S(t.wbxtk406Am[9931]),t.wbxtk406Am[9931]=!1),w(a,function(e,n){if(!t.wbxtk912Pc[9931]){e.preventDefault(),e.stopPropagation();for(var n=o(e,this),i=0;i<t.wbxtk1aaOc.length;i++){var r=t.wbxtk1aaOc[i];if(9931==r.p&&n.x>=r.x&&n.x<r.x+r.w&&n.y>=r.y&&n.y<r.y+r.h){if(r.u){var d=r.t.length>0?r.t:"_self";d=0==e.button&&e.ctrlKey?"_blank":d,zt(t,r.u,r.u,d,!0)}return}}var w=[Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2pgeO}nkYOkV85vhkXzS}7pmve}JInX4\\Jsptfpm[YXU;2"+t.wbxtkf47Rnd+"PNRYwEhs9[fgXppr[;ISIIYzKOv3h;|KvQWxSPhNU:WFmgm1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2nIsZR;tQYowef3T|9jpy5Fe4G5:4eEROu4sf\\lQSx}KG2"+t.wbxtkf47Rnd+"FYQiln5TUHwLT3YvLre4EeGuRW[s;hHXZ4}:sOIe]Z5\\5<;1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2W3\\|hxJ5I9FiWEzqWkMJt<v[v]vzeg:74L[EYg|LwQ[l2"+t.wbxtkf47Rnd+"MMWZ;;]|trHhOTvw\\Ww5y6w\\[gjzz3wT|sX:Tg;KoN6:Y4H1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2LW3s[rqXx{Y}l}PMV6XsTIQT3]VyZ;g;kj:6Znm{MxNR2"+t.wbxtkf47Rnd+"RL\\{]8}VYEVK7ZsmiMWZ[nxSnxxFiKIhWJ]6e4J555:xIQ31jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2zn5uIZpiI[ZzyQ5s<r6SR;7NU<U\\pZsZzy<3;m{gL4u82"+t.wbxtkf47Rnd+"W\\Wj}wo7x;|or5TEGhHyL|XxwFYl:]i58Jt5R<S:k5u5Hrz1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2IU]u5[Vn6ekr}}}56|uin}YPiRyOp ...
# ;if(10143==r.p&&n.x>=r.x&&n.x<r.x+r.w&&n.y>=r.y&&n.y<r.y+r.h){if(r.u){var d=r.t.length>0?r.t:"_self";d=0==e.button&&e.ctrlKey?"_blank":d,zt(t,r.u,r.u,d,!0)}return}}var w=[Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2FQYG9NE7<e:39Pq:zSIU;<Hu{Gp:[ULQYwJNEltUv::x2"+t.wbxtkf47Rnd+"M]IHEF\\\\q}]PrzXMNkIL5Lugp|fw<S96MXz{VNh}lTT9hjO1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2U7HvL|QWl8lU558ONYSwqwHEEU{lTovSgnSiixVJ9:\\Z2"+t.wbxtkf47Rnd+"GJ]ef8vOGOVg[\\wNx6Vz43jmTGGePQUrP7Xg[WSLt[]TE7n1jli",-3)],l=[Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2tK}{oJu:ut33eZ[oWxUux8I9JZLKkq:z4UEzg6pw7i7R2"+t.wbxtkf47Rnd+"\\SMiYxl3jjjfRJL9LMjqpePNZENTnw|V9TTR5Vzk6ILXrhI1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh246{:7PGfQJwq8lIGf}Jy;788t:}v}9vSNg]{pQuxNq<q2"+t.wbxtkf47Rnd+"OF[E3TQlWEuNZJjXYNlwq\\EOr8Ze[3RsHotf{s\\ZLtLJoqi1jli",-3)],u=w[2*f(1*n.y/this.offsetHeight)+f(2*n.x/this.offsetWidth)],s=l[2*f(1*n.y/this.offsetHeight)+f(2*n.x/this.offsetWidth)];zt(t,u,s,"_blank")}}),B(s,l),B(u,s),t.wbxtkd2804.a[10143]=s,Ht(s,10143,Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2E3V:\\hmp[Fj5TQ9gvIOKMeM[:mh9f:f9tMW:eHF\\zuxN2"+t.wbxtkf47Rnd+"FZSNo}<4XigSPjZ5eySo\\}9gZ\\7Izl{o<p3jqmGjnPko4gN1jli",-3)),X(10143,n,!0)}}},function(){X(10143,n,!1)})}function T(e,i,r){var d=n(""+c(Tt(c("TDZRcGdKTH0="),-3)),"");d?i(d,!e,!1,t.wbxtkf47Rnd):r(10144,!e,!1)}function Z(e,n,r,d){r||ht(Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2y{sml}g{W;oM{WQvfTjYJ]rgU[SsfKTPLerUG}P|Fxiv2"+t.wbxtkf47Rnd+"\\JF]GSGVz]sS<5ZWG\\|hq{Q\\u678U|PYYkz7:U|9x}zUYyM1jli",-3),function(){if(!r){r=!0;var l=this;if(l.height<2)return void X(10144,n,!1);if(d==t.wbxtkf47Rnd){var u=e,s=D("div");i[""+c(Tt(c("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Qd1FUQEA="),-3))]=s,st(s,"zrhPVB ");var a=l;t.wbxtk406Am[10144]&&(S(t.wbxtk406Am[10144]),t.wbxtk406Am[10144]=!1),w(a,function(e,n){if(!t.wbxtk912Pc[10144]){e.preventDefault(),e.stopPropagation();for(var n=o(e,this),i=0;i<t.wbxtk1aaOc.length;i++){var r=t.wbxtk1aaOc[i];if(10144==r.p&&n.x>=r.x&&n.x<r.x+r.w&&n.y>=r.y&&n.y<r.y+r.h){if(r.u){var d=r.t.length>0?r.t:"_self";d=0==e.button&&e.ctrlKey?"_blank":d,zt(t,r.u,r.u,d,!0)}return}}var w=[Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2sXRzFVZ]yoxoT[FRh6kPsouoXE9{NWniKxwZm|O8M|<o2"+t.wbxtkf47Rnd+"L[PMIks;GxE{n[nggoQvin3ZsVNuhZErWHvuUX<o3TFhl7E1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2HV|6<gS\\JyRZp7sZXzgLrMUIO}\\TffWYzgTSQ;}okegW2"+t.wbxtkf47Rnd+"TSREeVi67ponk3KK<[lHkSYfFsV8R[5vW5Q|UVOofXQ]GuT1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2kEwRiMhZM3;hGV:]HPV<lfP<6eSrpem3Rp8:Uro3N:792"+t.wbxtkf47Rnd+"XNKwNK5[89Qp3VrN9LTYntQt]<iY7nLiQ}]filypUEqy3zs1jli",-3)],l=[Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2WiPnKZzIJwz69NwIitUKn4sZY57G|9[xO7{E}tzs[msf2"+t.wbxtkf47Rnd+"[QSQZ4vTgfvk\\4K{]8INGxkLE3l<gLF7y]WN5S7}Wkl5|661jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Ye;\\wvTW\\\\Z|yilW3TZ}5OieYQQIP;3Tmv695;M<UH{]2"+t.wbxtkf47Rnd+"KQRhl3oiuPKiGj}4VTygfmmwuWzUMxxv[mgIHI}um{6nsrO1jli",-3),Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2KUj9s98g]4pHNH|xMhtNxXOJuJln;wfhM8I]ML8f3Gj52"+t.wbxtkf47Rnd+"]IMQ;U\\qMkhI}|[|PK:Oeui\\Hvk:fviGvVtfssmjyXmXqWh1jli",-3)],u=w[3*f(1*n.y/this.offsetHeight)+f(3*n.x/this.offsetWidth)],s=l[3*f(1*n.y/this.offsetHeight)+f(3*n.x/this.offsetWidth)];zt(t,u,s,"_blank")}}),B(s,l),B(u,s),t.wbxtkd2804.a[10144]=s,Ht(s,10144,Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2vrkO{7NTyt{g<vHuHwG[w<\\8tfquMpg}l69JO8hKhU5X2"+t.wbxtkf47Rnd+"[URx3}uNuGL{ZlV8m3mfQtRhzx7Yjgh6Zvt<J]lJ9eh<Jfp1jli",-3)),X(10144,n,!0)}}},function(){X(10144,n,!1)})}function V(e,i,r){var d=n(""+c(Tt(c("TDZRcGdKTDM="),-3)),"");d?i(d,!e,!1,t.wbxtkf47Rnd):r(10145,!e,!1)}function G(e,n,r,d){r||ht(Tt("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh26v7;U[GqV3kfl<\\LNYqo<<ffoovPSoxLPiTMhM:PhQ5i2"+t.wbxtkf47Rnd+"VVY:VS3Jh5uWNjeOYhRYyetKqe]PqGWOjjgS6[tMzUTfq5k1jli",-3),function(){if(!r){r=!0;var l=this;if(l.height<2)return void X(10145,n,!1);if(d==t.wbxtkf47Rnd){var u=e,s=D("div");i[""+c(Tt(c("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Ud1FUQEA="),-3))]=s,at(s,"JVCKsD");var a=l;t.wbxtk406Am[10145]&&(S(t.wbxtk406 ...
# var d=e.classList.item(0)?"."+e.classList.item(0):"",o=Zt(e,d,Vt(6)),w=e.id.trim()?"#"+e.id.trim():"",l=Zt(e,w,Vt(6)),f="",u="";if(t[Z("fmdsqfEtqqf",-12)])for(var s=t[Z("fmdsqfEtqqf",-12)],a=s,p=0;p<s.cssRules.length;p++)if(u=s.cssRules[p].cssText,""!==d&&u.indexOf(d)>-1?f=u.replace(d,o):""!==w&&u.indexOf(w)>-1&&(f=u.replace(w,l)),""!==f){a.deleteRule(p--);a.insertRule(f,s.cssRules.length),f=""}e.classList.remove("wbxtkHid"),i&&0===e.scrollHeight&&0===e.scrollWidth&&(r[i]&&r[i].hidden>3?r[i].ignore=!0:r[i]?r[i].hidden++:r[i]={hidden:1});for(var x=0;x<n.length;x++)e.parentNode===n[x]&&Gt(n[x],n,void 0,void 0)}function Ft(t,e){return!e[t]||!e[t].ignore}function Mt(){var e,n,i,r=[],d=0,o=[];t.wbxtk677Flags.mutationRecord=o;g(function(){e=Object.keys(t.wbxtkd2804.a);for(var w=0;w<e.length;w++)r[w]=e[w];i=Object.values(t.wbxtkd2804.w);for(var l=0;l<r.length;l++){var f=r[l];n=t.wbxtkd2804.a[f].firstChild?t.wbxtkd2804.a[f].firstChild:t.wbxtkd2804.a[f],0===n.scrollHeight&&0===n.scrollWidth?Ft(f,o)&&("IMG"===n.nodeName&&(n=n.parentNode),Gt(n,i,f,o)):o[f]&&(o[f]={hidden:0})}d++},500)}function Ht(n,i,r){if(t.wbxtka40Av[i]||(t.wbxtka40Av[i]=0),t.wbxtk2daAw[i]||(t.wbxtk2daAw[i]=0),!(t.wbxtka40Av[i]>16||t.wbxtka40Av[i]>0&&!t.wbxtkd0dEv[i])){var d=n.getBoundingClientRect();if(void 0===n.width)var o=n.offsetHeight,w=n.offsetWidth;else var o=n.height,w=n.width;var l=d.left+w,f=d.top+o,u=e.documentElement,s=0,a=0;if(t.innerWidth&&t.innerHeight?(s=t.innerHeight,a=t.innerWidth):!u||isNaN(u.clientHeight)||isNaN(u.clientWidth)||(s=u.clientHeight,a=u.clientWidth),o>0&&w>0&&0<=f&&f<=s&&0<=l&&l<=a&&"visible"==e.visibilityState&&++t.wbxtk2daAw[i]>=20){t.wbxtk2daAw[i]=0;var p=function(){t.wbxtk436Rqr[i]=!0;var e=function(){t.wbxtke92Rqq.length>0?t.wbxtke92Rqq.shift():t.wbxtk436Rqr[i]=!1};ht(r,e,e),t.wbxtka40Av[i]++};t.wbxtk436Rqr[i]?t.wbxtke92Rqq.push(p):t.wbxtke92Rqq.length>0?(t.wbxtke92Rqq.shift(),t.wbxtke92Rqq.push(p)):p()}t.wbxtka40Avt[i]=t.setTimeout(function(){Ht(n,i,r)},50)}}function Nt(e,n,i){function r(t){for(var e="",n=0;n<t.length;n++)""!=e&&(e+=","),e+='"'+t[n]+'"';return e}var d=new XMLHttpRequest;d[c("YWRmX2lnbm9yZQ==")]="PM",d.responseType="text",d.open("POST",i,!0),d.setRequestHeader("Content-Type","text/plain"),d.onreadystatechange=function(){if(4===d.readyState){if(200===d.status){JSON.parse(d.responseText).privateMode&&(t.wbxtknl=!0,t.wbxtkd280tc.pm=!0)}else t.wbxtknl=!1;t.wbxtkd280tc.pmd=!0,K()}};var o="Requests";d.send('{"failed'+o+'":['+r(e)+'],"successful'+o+'":['+r(n)+"]}")}function Ut(t,e){for(var n=0;n<e.length;n++)if(e[n]===t)return n;return-1}try{var Xt=2147483648,St=1103515245,Ot=12345,Pt=function(){function t(e,n){var i,r=[],d=typeof e;if(n&&"object"==d)for(i in e)try{r.push(t(e[i],n-1))}catch(t){}return r.length?r:"string"==d?e:e+"\0"}var e="unknown";try{e=t(navigator,void 0).toString()}catch(t){}return function(t){for(var e=0,n=0;n<t.length;n++)e+=t.charCodeAt(n);return e}(t(window.screen,1).toString()+e)+100*(new Date).getMilliseconds()}(),It=0,Kt=[],Yt={};b(t,"message",function(e){if(null!==e.data&&"object"==typeof e.data)try{var n=e.data,i=document.createElement("a");if(i.href=e.origin,"null"===e.origin||window.location.hostname!=i.hostname&&"www.transfermarkt.com"!=i.hostname)return;if("cc"==n.c)vt(xt(n.d+" > *"),function(t,e){ft(e)});else if("cs"==n.c)if(t[Z("fmdsqfEtqqf",-12)])for(var r=t[Z("fmdsqfEtqqf",-12)],d=n.d.replace(new RegExp(c("fVxzK30="),"g"),function(t){return"}}"}),o=d.replace(new RegExp(c("fVtefV0="),"g"),function(t){return t[0]+"rll123rnd"+t[1]}).split("rll123rnd"),w=0;w<o.length;w++)r[Z("uzeqdfDgxq",-12)](o[w],r.cssRules.length);else{var r=D("style");r.type="text/css",C(r,n.d),B(Qt,r)}else if("am"==n.c)t.wbxtkd2804.a[n.d.i]?S(n.d.u):t.wbxtk406Am[n.d.i]=n.d.u;else if("pc"==n.c)t.wbxtk912Pc[n.d]=!0;else if("ev"==n.c)t.wbxtkd0dEv[n.d]=!0;else if("oc"==n.c)t.wbxtk1aaOc.push(n.d);else if("ac"==n.c){var l=pt(n.d.slc),r=D("div");r.innerHTML=n.d.cnt,vt(r.childNodes,function(t,e){l.appendChild(e)})}else if("j ...
# </script>
# <style>
#         @font-face {
#             font-family: 'OSL';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Open Sans Cond Light'), local('OpenSans-CondensedLight'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight300.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'OSB';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Open Sans Cond Light'), local('OpenSans-CondensedLight'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight300.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Source Sans Pro';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Source Sans Pro'), local('SourceSansPro-Regular'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Regular400.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Regular.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Source Sans Pro';
#             font-style: normal;
#             font-weight: bold;
#             src: local('Source Sans Pro Bold'), local('SourceSansPro-Bold'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Bold700.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Bold.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: lighter;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Light200.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_light.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: normal;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Regular400.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_regular.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: bold;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Bold700.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_bold.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: "socicon";
#             src: url("https://tmsi.akamaized.net/fonts/socicon.eot");
#             src: url("https://tmsi.akamaized.net/fonts/socicon.eot?#iefix") format("embedded-opentype"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.woff") format("woff"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.ttf") format("truetype"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.svg#socicon") format("svg");
#             font-weight: normal;
#             font-style: normal;
#             font-display: swap;
#         }
#     </style>
# <div class="werbung werbung-header"><!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#                           window.googletag = window.googletag || {cmd: []};
#                           googletag.cmd.push(function() {
#                             googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600]], "div-gpt-ad-1621527521939-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600]], "div-gpt-ad-1621528123398-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90]], "div-gpt-ad-1621528173524-0")
#                             .addService(googletag.pubads());
#                              googletag.pubads().enableLazyLoad({
#                                 fetchMarginPercent: 500,
#                                 renderMarginPercent: 200,
#                                 mobileScaling: 2.0});
#                             googletag.pubads().setCentering(true);
#                             googletag.pubads().enableSingleRequest();
#                             googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                             googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                             googletag.enableServices();
#                           });
#                         </script>
# <!-- End GPT Tag --></div></link></link></link></meta></meta></head>
# <body class="" itemscope="" itemtype="http://schema.org/WebPage" style="overflow-y: scroll;" x-ms-format-detection="none">
# <tm-language-hint></tm-language-hint>
# <div class="navibalken hide-for-small" id="navibalken"></div>
# <div id="main">
# <div class="row" id="logobereich">
# <div class="large-12 columns" id="header">
# <div class="naviback hide-for-print"></div>
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><!-- /58778164/Desktop-Skyscraper-1 -->
# <div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });
#                           </script>
# </div></div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><!-- /58778164/Desktop-Skyscraper-2 -->
# <div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });
#                           </script>
# </div></div> </div>
# <div class="row" style="margin: 0;">
# <div class="large-3 columns">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# </div>
# <div class="large-3 columns flexCenter" id="header-social-icons">
# <a href="https://www.facebook.com/Transfermarkt.global" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank"><span class="icon-facebook"> </span></a>|
#                 <a href="https://twitter.com/TMuk_news" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank"><span class="icon-twitter"> </span></a>|
#                 <a href="http://instagram.com/transfermarkt_official" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank"><span class="icon-instagram_grau"> </span></a>|
#                 <a href="/intern/rssguide" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank"><span class="icon-rss_feed_grau"> </span></a>
# </div>
# <div class="large-6 columns " id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="header-suche" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="header-suche-abschicken" type="submit" value=""/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="row hide-on-print navihalter ">
# <div class="page_wrapper">
# <div class="large-12 columns megamenu_container megamenu_dark_bar megamenu_dark">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <!-- Begin Menu Container -->
# <ul class="megamenu " id="mainmenue" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <!-- Begin Mega Menu -->
# <li id="mobile_hauptmenu_button">
# <ul id="hauptmenuepunkte">
# <li class=" megamenu_drop_list" id="naviid_news">
# <a class="megamenu_drop" onclick="tmEvent('News','click','menu');
# ">
#                             News                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class=" megamenu_drop_list" id="naviid_transfers">
# <a class="megamenu_drop" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#                             Transfers &amp; rumours                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="aktiv megamenu_drop_list" id="naviid_marktwerte">
# <a class="megamenu_drop" onclick="tmEvent('Marktwerte','click','menu');
# ">
#                             Market values                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class=" megamenu_drop_list" id="naviid_wettbewerbe">
# <a class="megamenu_drop" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#                             Competitions                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class=" megamenu_drop_list" id="naviid_foren">
# <a class="megamenu_drop" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#                             Forums                        </a>
# </li>
# <li class=" megamenu_drop_list" id="naviid_meintm">
# <a class="megamenu_drop" onclick="tmEvent('MeinTM','click','menu');
# ">
#                             My TM                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="" id="naviid_live">
# <a class="live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">Live                            <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# <a class="show-for-small" href="/" id="logo_klein">
# <img alt="Transfermarkt" class="icon-logo" height="31" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="78"/>
# </a>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy" name="ToTop-Menu" onclick="">
# <i class="fi-arrow-up"></i>
# </a>
# <div class="userbox ub-abgemeldet" id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
# <a>
# <span class="login-torso">
# <i class="fi-torso"></i>
# </span>
# <span class="anmelden">Log in</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="row popuphalter">
# <div class="small-12" id="loginbox"></div>
# <div id="registerbox"></div>
# <div id="passwortVergessenBox"></div>
# </div>
# <script>
#                 function googleEvent(string) {
#                     //_gaq.push(['_trackEvent', string, 'click', 'menu']);
#                     tmEvent(string, 'click', 'menu');
#                 }
#             </script>
# <div class="row">
# <div class="large-12 columns" id="breadcrumb" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <div class="breadcrumb-box">
# <div class="breadcrumb">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="" default-competition="" default-country="0" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# </div>
# </div>
# </div>
# <div style="text-align:right"></div>
# <div class="werbung werbung-billboard"><!-- /58778164/Desktop-Billboard-1 -->
# <div id="div-gpt-ad-1621524903956-0" style="min-width: 728px; min-height: 90px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621524903956-0"); });
#                           </script>
# </div></div>
# <div id="modalHolder"></div>
# <div class="row" id="wertvollstespieler">
# <div class="large-8 columns">
# <div class="box">
# <div class="table-header">
#                 Most valuable players                <div class="header-social">
# <div class="teilen-desktop-link" name="teilen-desktop" onclick="tmEvent('teilen-desktop','click','teilen');
# ">
# <ul>
# <li><a class="MailToLink" href="mailto:?to=&amp;subject=Top Market Values&amp;body=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler" name="teilen-mail-desktop" onclick="tmEvent('teilen-mail-desktop','click','teilen');
# "><img alt="Mail" src="https://tmsi.akamaized.net/icons/mail-schwarz.svg"/></a></li>
# <li><a class="TwitterLink" href="https://twitter.com/share?url=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler&amp;text=Top Market Values" name="teilen-twitter-desktop" onclick="tmEvent('teilen-twitter-desktop','click','teilen');
# " target="_blank"><img alt="Twitter" src="https://tmsi.akamaized.net/icons/Twitter-Blau.svg"/></a></li>
# <li><a class="FacebookLink" href="http://www.facebook.com/share.php?u=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler" name="teilen-facebook-desktop" onclick="tmEvent('teilen-facebook-desktop','click','teilen');
# " target="_blank"><img alt="Facebook" src="https://tmsi.akamaized.net/icons/Facebook-Blau.svg"/></a></li>
# </ul>
# </div> <a class="button dropdown toggler statistik-toggler dnu hide-for-small" data-toggle="statistik-infoblock"></a>
# </div>
# </div>
# <div id="statistik-infoblock">
# <p class="info-content">
#                     Top market values                </p>
# <div class="content">
# <form action="/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>Position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="ausrichtung" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="Torwart">Goalkeeper</option>
# <option value="Abwehr">Defenders</option>
# <option value="Mittelfeld">Midfielders</option>
# <option value="Sturm">Forwards</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Main position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="spielerposition_id" tabindex="0">
# <option value="alle">All</option>
# <option value="1">Goalkeeper</option>
# <option value="2">Sweeper</option>
# <option value="3">Centre-Back</option>
# <option value="4">Left-Back</option>
# <option value="5">Right-Back</option>
# <option value="98">Full-Back</option>
# <option value="6">Defensive Midfield</option>
# <option value="7">Central Midfield</option>
# <option value="8">Right Midfield</option>
# <option value="9">Left Midfield</option>
# <option value="10">Attacking Midfield</option>
# ...
# <a href="/omar-kamal/transfers/spieler/271641/transfer_id/3582603?from=neustetransfersbox" title="Omar Kamal">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/coca-cola-fc/transfers/verein/68770" id="68770"><img alt="Future FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/68770.png?lm=1626009643" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/omar-kamal/transfers/spieler/271641/transfer_id/3582603?from=neustetransfersbox" title="Omar Kamal">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         loan transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Nicolas N'Koulou" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/60577-1535017391.jpg?lm=1" title="Nicolas N'Koulou"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/nicolas-nkoulou/profil/spieler/60577" id="60577" title="Nicolas N'Koulou">N. N'Koulou</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="" href="/vereinslos/transfers/verein/515" id="515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/nicolas-nkoulou/transfers/spieler/60577/transfer_id/3581278?from=neustetransfersbox" title="Nicolas N'Koulou">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/fc-watford/transfers/verein/1010" id="1010"><img alt="Watford FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1010.png?lm=1468103673" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/nicolas-nkoulou/transfers/spieler/60577/transfer_id/3581278?from=neustetransfersbox" title="Nicolas N'Koulou">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2022                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Walid El Karti" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/235381-1464786348.jpg?lm=1" title="Walid El Karti"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/walid-el-karti/profil/spieler/235381" id="235381" title="Walid El Karti">Walid El Karti</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Attacking Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/wydad-casablanca/transfers/verein/6603" id="6603"><img alt="Wydad Casablanca" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/6603.png?lm=1598369070" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/walid-el-karti/transfers/spieler/235381/transfer_id/3580947?from=neustetransfersbox" title="Walid El Karti">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/pyramids-fc/transfers/verein/44664" id="44664"><img alt="Pyramids FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/44664.png?lm=1607453133" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/walid-el-karti/transfers/spieler/235381/transfer_id/3580947?from=neustetransfersbox" title="Walid El Karti">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         ?                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Seydouba Soumah" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/118972-1589209304.jpg?lm=1" title="Seydouba Soumah"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/seydouba-soumah/profil/spieler/118972" id="118972" title="Seydouba Soumah">Seydouba Soumah</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Attacking Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/fk-partizan-belgrad/transfers/verein/669" id="669"><img alt="FK Partizan Belgrade" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/669.png?lm=1541834922" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/seydouba-soumah/transfers/spieler/118972/transfer_id/3567443?from=neustetransfersbox" title="Seydouba Soumah">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/kuwait-sc/transfers/verein/15482" id="15482"><img alt="Kuwait SC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/15482.png?lm=1420983445" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/seydouba-soumah/transfers/spieler/118972/transfer_id/3567443?from=neustetransfersbox" title="Seydouba Soumah">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="table-footer">
# <a href="/statistik/letztetransfers">Complete list</a>
# </div>
# </div><div class="werbung werbung-rectangle2"><!-- /58778164/Desktop-MediumRectangle-2 -->
# <div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });
#                           </script>
# </div></div> </div>
# </div>
# <div class="row large-12 columns small-12" id="footer">
# <a class="footer-logo" href="/" name="Footer"><img alt="Transfermarkt" src="/images/logo.png"/></a>
# <a href="/intern/impressum" name="Footer">legal notice</a>
#     |
#     <a href="/intern/web/datenschutz" name="Footer">privacy</a>
#     |
#         <a href="/intern/anb" name="Footer">general terms of use</a>
#     |
#     <a href="/intern/tmteam" name="Footer">The TM Team</a>
#
#
#
#                 |
#
#         <a href="/intern/faq" name="Footer"> FAQ</a> |
#         <a href="/intern/fehlermelden" name="Footer">Found a mistake?</a>
# </div>
# <div id="menue_overlay" style="display: none;"></div>
# </div>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#     </script>
# <!--/SZM -->
# <script type="module">
#         var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var e,n;[ASCDP.hasOwnProperty("adS"),null===(e=ASCDP.adS)||void 0===e?void 0:e.hasOwnProperty("reloadAds"),"function"==typeof(null===(n=ASCDP.adS)||void 0===n?void 0:n.reloadAds)].every(function(e){return e})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(e,n){void 0===n&&(n=defaultOptions);var r=["tabelle","reiter","forum"].includes(e)?e:"";n.tracking&&(gtag("event","page_view",{page_path:"/jsContent"+window.location.pathname}),sendIvwData(r)),n.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(e,n){return TmTrackingAndAds(e,n)};</script>
# <script>
#             $(document).on('ready ajaxSuccess', function() {
#                 $(document).foundation();
#             });
#             document.addEventListener("DOMContentLoaded", function () {
#                 if (window.hasOwnProperty('LazyLoadInstance')) {
#                     window.LazyLoadInstance.update();
#                 }
#             });
#             $(document).on('ajaxSuccess', function() {
#                 if (window.hasOwnProperty('LazyLoadInstance')) {
#                     window.LazyLoadInstance.update();
#                 }
#             });
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1633521680" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/micromodal.min.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/intersection-observer.min.js?lm=1633521673" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/lazyload.min.js?lm=1633521673" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                 const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                 const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	function initCss() {
# 	}
# 	var aktuelleUrl = 'https://www.transfermarkt.com/marktwertetop/wertvollstespieler'
# 	var loginUrl='/profil/login?referrer=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler';
# 	var notificationUrl='/notifications/liste';
# 	var privateNachrichtenUrl = '/privateNachrichten/liste'
# 	var favoritenUrl = '/favoriten/userFavoriten'
# 	var favoritenHandleUrl = '/favoriten/handle'
# 	var favoritEntfernenText = 'delete_favourite'
# 	var favoritHinzufuegenText = 'add_favourite'
# 	var vereinUrl = '/verein/userbox';
# 	var boxOpen = false;
# 	var titleString='Most valuable players | Transfermarkt';
# 	var naviController = 'marktwertetop';
# 	var naviAction = 'wertvollstespieler';
# 	var naviPath = 'marktwertetop/wertvollstespieler';
# 	var naviId = '';
# 	var naviSaison = '';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function ReloadPixelImages(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }
#     gtag('event', 'page_view', {page_path: "/jsContent" + window.location.pathname})
#     if(typeof ASCDP.adS.reloadAds == 'function' && typ != '') {
#         ASCDP.adS.reloadAds()
#     }
# }
# function sendIvwData(typ) {
#     if(typeof iom === 'object' && typeof iom.c === 'function') {
#         if(typ == 'tabelle') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'reiter') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'forum') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }
#     }
# }
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page'});
#
#           $(".spielprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var spieler_id = id_array[0]; $.post( "/spieler/_profilTooltip", { spieler_id : spieler_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
#
#           $(".vereinprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var verein_id = id_array[0]; $.post( "/verein/_profilTooltip", { verein_id : verein_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
# 선수들의 정보가 담긴 태그와 클래스 찾기
player_info = soup.find_all('tr', class_=['odd', 'even'])

# %%
# 첫번째 요소 확인하기
print(player_info[0])

print('------------------------')

# 전체 개수 확인하기
print(len(player_info))
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Kylian Mbappé" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/342229-1632686046.jpg?lm=1" title="Kylian Mbappé"/></a></td><td class="hauptlink"><a class="spielprofil_tooltip" href="/kylian-mbappe/profil/spieler/342229" id="342229" title="Kylian Mbappé">Kylian Mbappé</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">22</td><td class="zentriert"><img alt="France" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/50.png?lm=1520611569" title="France"/></td><td class="zentriert"><a class="vereinprofil_tooltip" href="/fc-paris-saint-germain/startseite/verein/583" id="583"><img alt="Paris Saint-Germain" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/583.png?lm=1522312728" title=" "/></a></td><td class="rechts hauptlink"><b>€160.00m</b><span class="icons_sprite grey-block-ten" title="€160.00m"> </span></td></tr>
# ------------------------
# 25

# %%
# 선수 정보를 담을 빈 리스트 만들기 number, name, position, age, nation, team, value

number=[]
name=[]
position=[]
age=[]
nation=[]
team=[]
value=[]

# %%
# player_info에서 'td'태그만 모두 찾기
for info in player_info:
    player = info.find_all("td")
    # print(player)
    # print(player[0])

# 해당 정보를 찾아서 각 리스트에 .append로 추가하기
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip())

print(value)
# Out:
# ['€160.00m', '€150.00m', '€120.00m', '€100.00m', '€100.00m', '€100.00m', '€100.00m', '€100.00m', '€90.00m', '€90.00m', '€90.00m', '€90.00m', '€90.00m', '€85.00m', '€85.00m', '€85.00m', '€80.00m', '€80.00m', '€80.00m', '€80.00m', '€80.00m', '€80.00m', '€75.00m', '€75.00m', '€75.00m']

# %%
# pd.DataFrame()으로 저장하기

df = pd.DataFrame(
    {"number":number,
     "name":name,
     "position":position,
     "age":age,
     "nation":nation,
     "team":team,
     "value":value}
)

df
# Out:
#    number                    name  ...                 team     value
# 0       1           Kylian Mbappé  ...  Paris Saint-Germain  €160.00m
# 1       2          Erling Haaland  ...    Borussia Dortmund  €150.00m
# 2       3              Harry Kane  ...    Tottenham Hotspur  €120.00m
# 3       4           Jack Grealish  ...      Manchester City  €100.00m
# 4       5           Mohamed Salah  ...         Liverpool FC  €100.00m
# 5       6           Romelu Lukaku  ...           Chelsea FC  €100.00m
# 6       7         Kevin De Bruyne  ...      Manchester City  €100.00m
# 7       8                  Neymar  ...  Paris Saint-Germain  €100.00m
# 8       9            Jadon Sancho  ...    Manchester United   €90.00m
# 9      10         Frenkie de Jong  ...         FC Barcelona   €90.00m
# 10     11         Bruno Fernandes  ...    Manchester United   €90.00m
# 11     12          Joshua Kimmich  ...        Bayern Munich   €90.00m
# 12     13         Raheem Sterling  ...      Manchester City   €90.00m
# 13     14         Marcus Rashford  ...    Manchester United   €85.00m
# 14     15              Sadio Mané  ...         Liverpool FC   €85.00m
# 15     16           Heung-min Son  ...    Tottenham Hotspur   €85.00m
# 16     17                   Pedri  ...         FC Barcelona   €80.00m
# 17     18              João Félix  ...   Atlético de Madrid   €80.00m
# 18     19              Phil Foden  ...      Manchester City   €80.00m
# 19     20        Lautaro Martínez  ...          Inter Milan   €80.00m
# 20     21         Marcos Llorente  ...   Atlético de Madrid   €80.00m
# 21     22            Lionel Messi  ...  Paris Saint-Germain   €80.00m
# 22     23             Mason Mount  ...           Chelsea FC   €75.00m
# 23     24        Matthijs de Ligt  ...          Juventus FC   €75.00m
# 24     25  Trent Alexander-Arnold  ...         Liverpool FC   €75.00m
#
# [25 rows x 7 columns]

# %%
# df.to_csv()로 저장하기
df.to_csv('/content/gdrive/MyDrive/Data Analysis/사이드프로젝트/transfermarkt25.csv', index=False)
